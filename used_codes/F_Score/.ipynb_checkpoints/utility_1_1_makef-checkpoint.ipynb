# %%
# モジュールの導入
import numpy as np
from scipy.special import lambertw as LW
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import axes3d
import statistics
import pandas as pd

# %%
# ユークリッド距離を返す関数
def distance(Noise_x, Noise_y, POI_x, POI_y):
    return np.sqrt( (Noise_x - POI_x)**2 + ( Noise_y - POI_y)**2 )

# %%
poi_true = 0
poi_false = 0

# %%
# POI検索関数
def PointOfInterest(poi_true, poi_false, Num, real_data, POI_data,
                   zx_list, zy_list, zt_list, verocity):
    poi_true = 0
    poi_false = 0
    for i in range(Num):
        t_ = real_data[2] + zt_list[i] + (distance(zx_list[0][i], zy_list[0][i], 
                                      POI_data[0], POI_data[1]) / verocity )
        if ( POI_data[2] > t_ ):
            poi_true += 1
        else:
            poi_false += 1
    return poi_true, poi_false

# %%
# 入力データ
# 実際の時空間データ(位置(0,0), 12時に出発)
real_data = [0, 0, 12]

# POIデータ
POI_data = [[4, 0,17],[8, 0,17],[12,0,17],
            [16,0,17],[20,0,17],[24,0,17],
            [28,0,17],[32,0,17],[36,0,17]]

# 移動速度
verocity = 4.0

# %%
# ランダム化された点の分布の数
Num = 10000

# %%
# POIの検索結果を格納するためのリスト
POI_result_list = []
POI_True_list = []
POI_False_list = []

# epsilonの値の定義
epsilon_z = [0.05, 0.1, np.log(2)/2, np.log(4)/2, 1.5, 5, 20]
epsilon_t = []
for i in range(len(epsilon_z)):
    epsilon_t.append(epsilon_z[i] * verocity)

# %%
zx_list = []
zy_list = []
zt_list = []

# %%
# ノイズ生成
theta = np.random.uniform(0,2*np.pi,Num)

p_z = np.random.uniform(0,1,Num)
p_t = np.random.uniform(0,1,Num)

# %%
# path_w = 'Utility_1_1.txt'
list_first = []
list_utility_1 = []

# %%
for i in range(len(epsilon_z)):
    if epsilon_z[i] != 0:
        for j in range(len(POI_data)):
            for k in range(100):
                W = LW( ((p_z - 1) / np.e), k = -1 )
                r = ( -1 / epsilon_z[i] ) * ( W + 1 )
                
                zx = real_data[0] + r * np.cos(theta)
                zx_list.append(np.array(zx))
                zy = real_data[1] + r * np.sin(theta)
                zy_list.append(np.array(zy))
                
                # EX ノイズを付与 1:1
                pp = 1
                for l in range(Num):
                    if p_t[l] <= (1/(pp+1)):
                        zt_list.append((2/epsilon_t[i]) * np.log((pp+1)*p_t[l]))
                    elif p_t[j] < 1:
                        zt_list.append(((2*pp)/epsilon_t[i]) * np.log( (pp/((pp+1)*(1-p_t[l])))) )
                
                POI_result_list.append(PointOfInterest(poi_true, poi_false, Num, real_data, POI_data[j],zx_list, zy_list, zt_list, verocity))
                
                zx_list = []
                zy_list = []
                zt_list = []
            for m in range(100):
                POI_True_list.append(POI_result_list[m][0])
                POI_False_list.append(POI_result_list[m][1])
            true_mean = statistics.mean(POI_True_list)
            false_mean = statistics.mean(POI_False_list)
            """
            with open(path_w, mode='a') as f:
                f.write("POI -> ")
                f.write(str(POI_data[j]))
                f.write(", epsilon(xy) = ")
                f.write(str(epsilon_z[i]))
                f.write(",epsilon(t) = ")
                f.write(str(epsilon_t[i]))
                f.write("の時\n")
                f.write("trueの平均値 = ")
                f.write(str(true_mean))
                f.write(", falseの平均値 = ")
                f.write(str(false_mean))
                f.write("\n")
            """
            list_first.append((true_mean,false_mean))
            
            # POIに関するリストの解放
            POI_result_list = []
            POI_True_list = []
            POI_False_list = []
        list_utility_1.append(list_first)
        list_first = []
print("done")

# %%
index1 = []
columns1 = []
for i in range(len(epsilon_z)):
    index1.append("eps_z= "+str(epsilon_z[i]*2))
for i in range(len(POI_data)):
    columns1.append(tuple(POI_data[i]))

# %%
# pd.DataFrame(data=list_second, index=index1, columns=columns1)
# Out:
#                              (4, 0, 17)    (8, 0, 17)   (12, 0, 17)  \
# eps_z= 0.1                 (3601, 6399)  (3570, 6430)  (3485, 6515)
# eps_z= 0.2                 (5138, 4862)  (4996, 5004)  (4701, 5299)
# eps_z= 0.6931471805599453   (9256, 744)  (8856, 1144)  (8014, 1986)
# eps_z= 1.3862943611198906    (9954, 46)   (9851, 149)   (9450, 550)
# eps_z= 3.0                   (10000, 0)     (9999, 1)    (9976, 24)
# eps_z= 10                    (10000, 0)    (10000, 0)    (10000, 0)
# eps_z= 40                    (10000, 0)    (10000, 0)    (10000, 0)
#
#                             (16, 0, 17)   (20, 0, 17)   (24, 0, 17)  \
# eps_z= 0.1                 (3394, 6606)  (3279, 6721)  (3143, 6857)
# eps_z= 0.2                 (4324, 5676)  (3932, 6068)  (3492, 6508)
# eps_z= 0.6931471805599453  (6602, 3398)  (4706, 5294)  (2851, 7149)
# eps_z= 1.3862943611198906  (8174, 1826)  (4851, 5149)  (1665, 8335)
# eps_z= 3.0                  (9601, 399)  (4924, 5076)   (371, 9629)
# eps_z= 10                    (10000, 0)  (4979, 5021)    (0, 10000)
# eps_z= 40                    (10000, 0)  (4992, 5008)    (0, 10000)
#
#                             (28, 0, 17)   (32, 0, 17)
# eps_z= 0.1                 (3004, 6996)  (2832, 7168)
# eps_z= 0.2                 (3071, 6929)  (2672, 7328)
# eps_z= 0.6931471805599453  (1611, 8389)   (864, 9136)
# eps_z= 1.3862943611198906   (456, 9544)   (109, 9891)
# eps_z= 3.0                   (14, 9986)    (0, 10000)
# eps_z= 10                    (0, 10000)    (0, 10000)
# eps_z= 40                    (0, 10000)    (0, 10000)
